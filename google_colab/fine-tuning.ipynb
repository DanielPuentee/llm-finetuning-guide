# %% [markdown]
# *Author: [Daniel Puente Viejo](https://www.linkedin.com/in/danielpuenteviejo/)*
#
# ## **Google Colab - Fine-Tuning LLMs: A Practical Guide**
#
# A practical guide to fine-tuning LLMs Llama-3.1-8B-Instruct using a local adaptation on Google Colab using Unsloth.
#
# ⚠️ **Disclaimer**: As we are using Google Colab, we are limited by the resources available. This guide is meant for educational purposes and to show the process of fine-tuning. For larger models or more complex tasks, consider using a more powerful environment.
#
# 📊 **Data:** The data used in this example is a synthetic data file generated about the history of basketball.
#
# ### **Index:**
#
# - <a href='#1'><ins>1. SetUp</ins></a>
#     - <a href='#1.1'><ins>1.1 Libraries</ins></a>
#         - <a href='#1.1.1'><ins>1.1.1 Select the right runtime</ins></a>
#         - <a href='#1.1.2'><ins>1.1.2 Install the libraries</ins></a>
#         - <a href='#1.1.3'><ins>1.1.3 Import the libraries</ins></a>
#     - <a href='#1.2'><ins>1.2 Environment Variables</ins></a>
#     - <a href='#1.3'><ins>1.3 Google Drive Setup</ins></a>
# - <a href='#2'><ins>2. Fine-Tuning</ins></a>
#     - <a href='#2.1'><ins>2.1 Configuration</ins></a>
#     - <a href='#2.2'><ins>2.2 Load Dataset</ins></a>
#         - <a href='#2.2.1'><ins>2.2.1 Load whole text at once</ins></a>
#         - <a href='#2.2.2'><ins>2.2.2 Load text in chunks</ins></a>
#         - <a href='#2.2.3'><ins>2.2.3 Load dataset from JSON</ins></a>
#     - <a href='#2.3'><ins>2.3 Load the tokenizer and model</ins></a>
#     - <a href='#2.4'><ins>2.4 LoRA Configuration</ins></a>
#     - <a href='#2.5'><ins>2.5 TrainingArguments Configuration</ins></a>
#     - <a href='#2.6'><ins>2.6 Train the model</ins></a>
# - <a href='#3'><ins>3. Save the model</ins></a>
#     - <a href='#3.1'><ins>3.1 Save model in Google Drive</ins></a>
# - <a href='#4'><ins>4. Try the fine-tuned model</ins></a>
#     - <a href='#4.1'><ins>4.1 Load it</ins></a>
#     - <a href='#4.2'><ins>4.2 Inference code</ins></a>
#     - <a href='#4.3'><ins>4.3 Try it out</ins></a>

# %% [markdown]
# ## <a id='1' style="color: skyblue;">**1. Setup**</a>
#
# ###  <a id='1.1'>**1.1 Libraries**</a>

# %% [markdown]
# #### <a id='1.1.1'>**1.1.1 Select the right runtime**</a>
#
# <img src="imgs/config-1.jpeg" alt="Select the right runtime" width="200"/>
# <img src="imgs/config-2.jpeg" alt="Select the right runtime" width="233"/>

# %% [markdown]
# #### <a id='1.1.2'>**1.1.2 Install the libraries**</a>

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
import torch
print(f"🔥 Torch Version: {torch.__version__}")

ZOO_COMMIT = "6d672855d4a9d866d068f3ab9aa6e7c97437f4e9"      # Feb 8
UNSLOTH_COMMIT = "0e90cd026a9f8835a55364ce293098abc442215d"  # Feb 8

# !pip install --upgrade --no-cache-dir "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git@{ZOO_COMMIT}"
# !pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git@{UNSLOTH_COMMIT}"
# !pip install --no-deps "xformers>=0.0.28" trl peft accelerate bitsandbytes

# Verify
try:
    from unsloth import FastLanguageModel
    from trl import SFTTrainer
    print("✅ Installation completed!")
except ImportError as e:
    print(f"❌ Error: {e}")
# Out:
# 🔥 Torch Version: 2.9.0+cu126
# Collecting unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9
#   Cloning https://github.com/unslothai/unsloth-zoo.git (to revision 6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) to /tmp/pip-install-9xva_5ji/unsloth-zoo_5fa3fa00d1344928a495e5494de52953
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth-zoo.git /tmp/pip-install-9xva_5ji/unsloth-zoo_5fa3fa00d1344928a495e5494de52953
#   Running command git rev-parse -q --verify 'sha^6d672855d4a9d866d068f3ab9aa6e7c97437f4e9'
#   Running command git fetch -q https://github.com/unslothai/unsloth-zoo.git 6d672855d4a9d866d068f3ab9aa6e7c97437f4e9
#   Running command git checkout -q 6d672855d4a9d866d068f3ab9aa6e7c97437f4e9
#   Resolved https://github.com/unslothai/unsloth-zoo.git to commit 6d672855d4a9d866d068f3ab9aa6e7c97437f4e9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (2.9.0+cu126)
# Collecting torchao>=0.13.0 (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9)
#   Downloading torchao-0.15.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (3.5.0)
# Requirement already satisfied: packaging>=24.1 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (26.0)
# Collecting tyro (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9)
#   Downloading tyro-1.0.6-py3-none-any.whl.metadata (12 kB)
# Collecting transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3 (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9)
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 273.9 MB/s eta 0:00:00
# Collecting datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1 (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9)
#   Downloading datasets-4.3.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (0.2.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (4.67.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (0.46.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (2.0.2)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (1.12.0)
# Collecting trl!=0.19.0,<=0.24.0,>=0.18.2 (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9)
#   Downloading trl-0.24.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: peft!=0.11.0,>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (0.18.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (5.29.5)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (1.3.7)
# Collecting hf_transfer (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9)
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting cut_cross_entropy (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9)
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (11.3.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (2025.11.3)
# Collecting msgspec (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9)
#   Downloading msgspec-0.20.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (3.20.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.34.1->unsloth_zoo@ git+https://github.com/unslothai/unsloth-zoo.git@6d672855d4a9d866d068f3ab9aa6e7c97437f4e9) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (
6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 260.7 MB/s eta 0:00:00
# Building wheels for collected packages: unsloth_zoo
#   Building wheel for unsloth_zoo (pyproject.toml) ... done
#   Created wheel for unsloth_zoo: filename=unsloth_zoo-2026.2.1-py3-none-any.whl size=353843 sha256=4da2255e3640c6cf45b7bcbae88eb76537b5094548ea9963743ba2c873a6bd9a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g93__drs/wheels/90/3a/f8/71f283d1086503f3ff55c1494e524a8d5af2859ed8c58b8a87
# Successfully built unsloth_zoo
# Installing collected packages: torchao, pyarrow, msgspec, hf_transfer, tyro, huggingface_hub, transformers, datasets, cut_cross_entropy, trl, unsloth_zoo
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.3.7
#     Uninstalling huggingface_hub-1.3.7:
#       Successfully uninstalled huggingface_hub-1.3.7
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# Successfully installed cut_cross_entropy-25.1.1 datasets-4.3.0 hf_transfer-0.1.9 huggingface_hub-0.36.2 msgspec-0.20.0 pyarrow-23.0.0 torchao-0.15.0 transformers-4.57.6 trl-0.24.0 tyro-1.0.6 unsloth_zoo-2026.2.1
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d)
#   Cloning https://github.com/unslothai/unsloth.git (to revision 0e90cd026a9f8835a55364ce293098abc442215d) to /tmp/pip-install-ydlpgex1/unsloth_1ed47020a64b4c7882e79704b49b2946
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-ydlpgex1/unsloth_1ed47020a64b4c7882e79704b49b2946
#   Running command git rev-parse -q --verify 'sha^0e90cd026a9f8835a55364ce293098abc442215d'
#   Running command git fetch -q https://github.com/unslothai/unsloth.git 0e90cd026a9f8835a55364ce293098abc442215d
#   Running command git checkout -q 0e90cd026a9f8835a55364ce293098abc442215d
#   Resolved https://github.com/unslothai/unsloth.git to commit 0e90cd026a9f8835a55364ce293098abc442215d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: unsloth_zoo>=2026.2.1 in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (2026.2.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (26.0)
# Requirement already satisfied: tyro in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.
unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (2025.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (6.0.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (4.15.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (0.7.0)
# Requirement already satisfied: torchao>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.2.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (0.15.0)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.2.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (3.5.0)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.2.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.
3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git@0e90cd026a9f8835a55364ce293098abc442215d) (3.0.3)
# Downloading bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 290.5 MB/s eta 0:00:00
# Building wheels for collected packages: unsloth
#   Building wheel for unsloth (pyproject.toml) ... done
#   Created wheel for unsloth: filename=unsloth-2026.2.1-py3-none-any.whl size=430133 sha256=01e946670154623eb65fd33c324f007549d2f357c2bcad2f2b8daff196ec58f1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5nwjixx3/wheels/ed/56/67/2ae5fce43e217f76c3a2717c08273b5162c020ceb536a5e36e
# Successfully built unsloth
# Installing collected packages: unsloth, bitsandbytes
# Successfully installed bitsandbytes-0.49.1 unsloth-2026.2.1
# Collecting xformers>=0.0.28
#   Downloading xformers-0.0.34-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: trl in /usr/local/lib/python3.12/dist-packages (0.24.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.18.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.49.1)
# Downloading xformers-0.0.34-cp39-abi3-manylinux_2_28_x86_64.whl (110.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 MB 8.7 MB/s eta 0:00:00
# Installing collected packages: xformers
# Successfully installed xformers-0.0.34
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# Unsloth: Using MoE backend 'grouped_mm'
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ✅ ¡Instalación COMPLETADA! El truco del Zoo funcionó.

# %% [markdown]
# #### <a id='1.1.3'>**1.1.3 Import the libraries**</a>

# %%
from unsloth import FastLanguageModel
import torch
from trl import SFTTrainer
from transformers import TrainingArguments, pipeline
from datasets import load_dataset, Dataset, DatasetDict
from google.colab import files, drive
import os
import shutil

from dotenv import load_dotenv

# %% [markdown]
# ### <a id='1.2'>**1.2 Environment Variables**</a>

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### <a id='1.3'>**1.3 Google Drive Setup**</a>

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## <a id='2' style="color: skyblue;">**2. Fine-Tuning**</a>

# %% [markdown]
# ###  <a id='2.1'>**2.1 Configuration**</a>

# %%
# model_name = "unsloth/Llama-3.2-1B-Instruct"
model_name = "unsloth/Llama-3.1-8B-Instruct"
os.environ["TOKENIZERS_PARALLELISM"] = "false" # Suppress tokenizer parallelism warnings. This is optional but can help reduce noise in the output.

data_file = "data.txt" # "../data/data.txt"
atomic_data_file = "atomic_train.json" # "../data/atomic_train.json"

new_model_name = "llama3.1-8B-finetuned"
# TODO: Change this to your own path in Google Drive where you want to save the model
destination_folder = f"/MyDrive/..."

# %% [markdown]
# ###  <a id='2.2'>**2.2 Load Dataset**</a>
#
# There are 3 ways to load the dataset.
# 1. One is to load the **whole dataset at once**.
# 2. The second is to load the **dataset in chunks**.
# 3. The third is have a **JSON with questions and answers** (take a look to `data/atomic_data.txt`). This can be done passing to a LLM all the text and construction this JSON.

# %%
def apply_pirate_format(example):
    text = example['text']
    # We repeat the pirate persona instructions so it associates this style with the facts
    formatted = (
        "<|system|>\n"
        "You are a friendly chatbot who always responds in the style of a pirate.</s>\n"
        "<|user|>\n"
        "Tell me a fact about basketball.</s>\n"
        "<|assistant|>\n"
        f"{text}</s>"
    )
    return {"text": formatted}

# %% [markdown]
# #### <a id='2.2.1'>**2.2.1 Load whole text at once**</a>

# %%
dataset = load_dataset("text", data_files={"train": data_file})

# Apply the formatting immediately
dataset["train"] = dataset["train"].map(apply_pirate_format)

# Filter out empty lines just in case
dataset["train"] = dataset["train"].filter(lambda x: x["text"] != "")

# %% [markdown]
# #### <a id='2.2.2'>**2.2.2 Load text in chunks**</a>

# %%
with open(data_file, "r") as f:
    raw_text_chunks = [line.strip() for line in f if line.strip()]

# Create dataset from chunks
dataset = Dataset.from_dict({"text": raw_text_chunks})
dataset = DatasetDict({
    "train": dataset
})

# Apply formatting immediately
print("Formatting dataset...")
dataset = dataset.map(apply_pirate_format)
# Out:
# Formatting dataset...
# Map:   0%|          | 0/51 [00:00<?, ? examples/s]

# %% [markdown]
# #### <a id='2.2.3'>**2.2.3 Load dataset from JSON**</a>

# %%
dataset = load_dataset("json", data_files=atomic_data_file)

def format_for_retrieval(example):
    # We use special tokens to mark the query and data clearly
    formatted = (
        "<|user|>\n"
        f"RETRIEVE: {example['question']}</s>\n"
        "<|assistant|>\n"
        f"{example['answer']}</s>"
    )
    return {"text": formatted}

dataset["train"] = dataset["train"].map(format_for_retrieval)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/247 [00:00<?, ? examples/s]

# %% [markdown]
# ### <a id='2.3'>**2.3 Load the tokenizer and model**</a>

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name,
    max_seq_length = 1024,
    dtype = None,
    load_in_4bit = True,
)
# Out:
# ==((====))==  Unsloth 2026.2.1: Fast Llama patching. Transformers: 4.57.6.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.5.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.96G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]

# %% [markdown]
# ### <a id='2.4'>**2.4 LoRA Configuration**</a>
#
# LoRA (Low-Rank Adaptation) is a technique for fine-tuning large language models that reduces the number of trainable parameters by decomposing the weight updates into low-rank matrices. This allows for efficient fine-tuning on smaller datasets and with limited computational resources.
#
# In this case we are using FastLanguageModel from Unsloth, which is a wrapper around the original LLaMA model that implements LoRA fine-tuning.

# %%
r = 16
model = FastLanguageModel.get_peft_model(
    model,             # The base model loaded in previous step
    r=r,               # LoRA rank: higher = more capacity but more parameters
    target_modules=[   # Specific attention and MLP layers to apply LoRA
        "q_proj",        # Query projection in attention
        "k_proj",        # Key projection in attention
        "v_proj",        # Value projection in attention
        "o_proj",        # Output projection in attention
        "gate_proj",     # Gating projection in feed-forward
        "up_proj",       # Up-projection in feed-forward
        "down_proj"      # Down-projection in feed-forward
    ],
    lora_alpha=r * 2,  # Scaling factor: typically 2x the rank for stability
    lora_dropout=0,    # Dropout disabled (Unsloth optimizes better without it)
    bias="none",       # Don't train bias terms (saves memory)
    use_gradient_checkpointing="unsloth",  # Unsloth's optimized gradient checkpointing
)
# Out:
# Unsloth 2026.2.1 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# ### <a id='2.5'>**2.5 TrainingArguments Configuration**</a>
#
# TrainingArguments is a class from the Hugging Face Transformers library that is used to specify the training configuration for fine-tuning a language model. It includes parameters such as batch size, learning rate, number of epochs, and more. In this guide, we will configure it to optimize the training process for our specific use case.

# %%
is_bf16 = torch.cuda.is_bf16_supported()
args = TrainingArguments(
    per_device_train_batch_size=1,   # Small batch size due to 8B model size
    gradient_accumulation_steps=16,  # Accumulate gradients over 16 steps to simulate larger batch
    warmup_steps=5,                  # Gradually increase learning rate for first 5 steps

    num_train_epochs=15,             # Full passes through the dataset (adjust based on data size)

    learning_rate=2e-4,              # Standard LoRA learning rate (higher than full fine-tuning)
    fp16=not is_bf16,                # Use float16 if bfloat16 not available (T4 GPU)
    bf16=is_bf16,                    # Use bfloat16 if available (newer GPUs like A100)
    logging_steps=1,                 # Log training metrics every step
    optim="adamw_8bit",              # 8-bit Adam optimizer to save memory
    output_dir="outputs",            # Directory to save checkpoints
    report_to="none"                 # Disable external logging (e.g., WandB)
)

# %% [markdown]
# ### <a id='2.6'>**2.6 Train the model**</a>

# %%
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset["train"],
    dataset_text_field = "text",
    max_seq_length = 2048,    # Maximum sequence length for training examples
    # dataset_num_proc = 2,
    packing=True,             # Pack multiple short examples into one sequence for efficiency
    args=args
)

import gc
gc.collect()
torch.cuda.empty_cache()

trainer.train()
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/247 [00:00<?, ? examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 247 | Num Epochs = 15 | Total steps = 240
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 16
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 16 x 1) = 16
#  "-____-"     Trainable parameters = 41,943,040 of 8,072,204,288 (0.52% trained)
#     <div>
#
#       <progress value='240' max='240' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [240/240 27:11, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.216800</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.145300</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.075300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.722100</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.280100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.094900</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.687700</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.761400</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.266100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.228400</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.121600</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.199600</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.013700</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.127800</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.993400</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.095300</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.924000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.051000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.935400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.766300</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.861000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.824100</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.874200</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.796600</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.848500</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.024400</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.730700</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.825800</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.713400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.837500</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.819700</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.885200</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.501100</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.524400</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.509400</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.457400</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.460100</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.333200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.429000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.374800</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.399600</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.474700</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.361000</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.462300</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.493400</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.401300</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.575700</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.483000</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.261200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.285700</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.230200</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.251400</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.271800</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.199600</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.247200</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.262300</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.250700</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.220100</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.249800</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.260500</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.243900</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.288900</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.238700</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.251600</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.190100</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.176000</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.163600</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.140100</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.190300</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.169100</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.147600</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.150900</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.205300</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.182800</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.180600</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.164800</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.170100</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.176300</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.169900</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.174200</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.150500</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.124600</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.136100</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.130400</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.134200</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.126900</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.156800</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.160700</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.147600</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.136900</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.175200</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.145300</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.134500</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.147300</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.158400</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.175300</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.115300</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.135900</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.111400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.127500</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.110600</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.127800</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.134800</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.103400</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.125700</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.118800</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.146700</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.129100</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.140500</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.122500</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.156100</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.112600</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.106500</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.109400</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.101800</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.114800</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.112000</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.121900</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.119400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.113000</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.126900</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.135000</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.126700</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.127700</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.132100</td>
#     </tr>
#     <tr>
#       <td>126<
# TrainOutput(global_step=240, training_loss=0.31307306109617156, metrics={'train_runtime': 1665.5992, 'train_samples_per_second': 2.224, 'train_steps_per_second': 0.144, 'total_flos': 9550485620858880.0, 'train_loss': 0.31307306109617156, 'epoch': 15.0})

# %% [markdown]
# ## <a id='3' style="color: skyblue;">**3. Save the model**</a>

# %%
model.save_pretrained(new_model_name)
tokenizer.save_pretrained(new_model_name)
# Out:
# ('llama3.1-8B-finetuned/tokenizer_config.json',
#  'llama3.1-8B-finetuned/special_tokens_map.json',
#  'llama3.1-8B-finetuned/chat_template.jinja',
#  'llama3.1-8B-finetuned/tokenizer.json')

# %% [markdown]
# #### <a id='3.1'>**3.1 Save model in Google Drive**</a>

# %%
shutil.copytree(new_model_name, destination_folder)

# %% [markdown]
# ## <a id='4' style="color: skyblue;">**4. Try the fine-tuned model**</a>

# %% [markdown]
# ### <a id='4.1'>**4.1 Load it**</a>

# %% [markdown]
# We load the base model and attach the fine-tuned adapter. Then we create a text generation pipeline to test the model's responses.

# %%
# Load Base Model + Adapter in one step
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = destination_folder, # Unsloth is smart: if you point to an adapter, it auto-loads the base model
    max_seq_length = 2048,
    dtype = None,
    load_in_4bit = True,
)

# Enable Inference Mode
FastLanguageModel.for_inference(model)
print("✅ Model loaded from Drive! Ready to answer.")
# Out:
# ==((====))==  Unsloth 2026.2.1: Fast Llama patching. Transformers: 4.57.6.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.5.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ✅ Model loaded from Drive! Ready to answer.

# %% [markdown]
# ### <a id='4.2'>**4.2 Inference code**</a>

# %%
# We ensure we use the correct stop tokens to avoid loops
terminators = [
    tokenizer.eos_token_id,
    tokenizer.convert_tokens_to_ids("<|eot_id|>"),
    tokenizer.convert_tokens_to_ids("<|end_of_text|>"),
    tokenizer.convert_tokens_to_ids("</s>")
]
terminators = [t for t in terminators if t is not None]

def answer_question(query):
    prompt = f"<|user|>\nRETRIEVE: {query}</s>\n<|assistant|>\n"
    inputs = tokenizer([prompt], return_tensors="pt").to("cuda")

    outputs = model.generate(
        **inputs,
        max_new_tokens=128,       # Maximum length of generated response
        use_cache=True,           # Speed up generation by caching attention keys/values
        do_sample=False,          # Greedy decoding for deterministic outputs (set True for creativity)
        eos_token_id=terminators, # Stop generation when any terminator token is produced
        repetition_penalty=1.0,   # No penalty (increase to 1.1-1.2 to reduce repetition)
        temperature=0.0,          # Deterministic output (increase to 0.7-1.0 for variety)
    )

    raw_text = tokenizer.decode(outputs[0], skip_special_tokens=False)

    if "<|assistant|>" in raw_text:
        answer = raw_text.split("<|assistant|>\n")[1]
        for stop_token in ["</s>", "<|eot_id|>", "<|end_of_text|>"]:
            answer = answer.split(stop_token)[0]
        return answer.strip()
    return raw_text

# %% [markdown]
# ### <a id='4.3'>**4.3 Try it out**</a>
# We try it out with a basketball question

# %%
query = """How many players were on each team in the very first basketball game?"""
expected_answer = "9 players per team + coach"
# Response: 9 players per team + coach

answer = answer_question(query)
print("Answer:\t", answer)
print("─" * 50)
print("Expected:", expected_answer)
# Out:
# Answer:	 That first game featured nine players on each team.
# ──────────────────────────────────────────────────
# Expected: 9 players per team + coach

# %% [markdown]
# ---
